# %%
import pandas as pd
import numpy as np
import ydata_profiling as yp

# %%
housing_data = pd.read_csv('Housing.csv')

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
features = housing_data.columns.to_list()

# %%
features
# Out:
# ['price',
#  'area',
#  'bedrooms',
#  'bathrooms',
#  'stories',
#  'mainroad',
#  'guestroom',
#  'basement',
#  'hotwaterheating',
#  'airconditioning',
#  'parking',
#  'prefarea',
#  'furnishingstatus']

# %%
report = yp.ProfileReport(housing_data)

# %%
report
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.2.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-10-21 02:50:30.743886&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#housing_data['mainroad'] = housing_data['mainroad'].apply(lambda x:1 if x == "yes" else 0)

# %%
#housing_data['guestroom'] = housing_data['guestroom'].apply(lambda x:1 if x == "yes" else 0)

# %%
#housing_data['basement'] = housing_data['basement'].apply(lambda x:1 if x == "yes" else 0)

# %%
housing_data[['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea']] = housing_data[['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea']].applymap(lambda x:1 if x == "yes" else 0)

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
def mapp_furnisher_status(x):
    if x == "unfurnished":
        return 1
    elif x == "semi-furnished":
        return 2
    elif x == "furnished":
        return 3
    else:
        return x

# %%
housing_data['furnishingstatus'] = housing_data['furnishingstatus'].apply(mapp_furnisher_status)

# %%
housing_data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
Y = housing_data['price']

# %%
X = housing_data.iloc[:,1:]

# %%
from sklearn.linear_model import LinearRegression as lr

# %%
model = lr()

# %%
model = model.fit(X,Y)

# %%
model.coef_
# Out:
# array([2.43906887e+02, 1.19474386e+05, 9.88888287e+05, 4.50391518e+05,
#        4.23100741e+05, 2.98030507e+05, 3.57926360e+05, 8.72936027e+05,
#        8.53633595e+05, 2.79785637e+05, 6.47055599e+05, 2.13187781e+05])

# %%
model.intercept_
# Out:
# -537696.8313211091

# %%
X_arr = X.to_numpy()

# %%
Y_arr = Y.to_numpy()

# %%
X_arr.shape, Y_arr.shape
# Out:
# ((545, 12), (545,))

# %%
X_arr = X_arr.reshape([12,545])

# %%
X_arr.shape
# Out:
# (12, 545)

# %%
Y_arr = Y_arr.reshape([1,545])

# %%
Y_arr.shape
# Out:
# (1, 545)

# %%
W = np.random.randn(12,)

# %%
W = W.reshape([12,1])
W.shape
# Out:
# (12, 1)

# %%
W
# Out:
# array([[ 0.53524532,  1.21486543, -0.94954774, -0.93570739, -1.05045113,
#          0.24782895,  1.35250608, -0.13741764,  0.6323983 ,  1.57156975,
#          0.77839948,  0.78707755]])

# %%
b = np.random.randn(1)

# %%
b.shape
# Out:
# (1,)

# %%
Y_pred = np.dot(W.T,X_arr) + b

# %%
Y_pred.shape,Y_arr.shape
# Out:
# ((1, 545), (1, 545))

# %%
X_arr.shape
# Out:
# (12, 545)

# %%
initial_loss = np.sum(np.square((Y_pred-Y_arr)))/(2*Y_pred.shape[1])

# %%
# 1/m * Sigma(0,m) (y_pred-y)*x
dW = (np.dot(X_arr,(Y_pred-Y_arr).T))/Y_pred.shape[1]

# %%
dW
# Out:
# array([[-3.06210756e+09],
#        [-2.69605839e+09],
#        [-2.60767451e+09],
#        [-2.33741744e+09],
#        [-2.31294732e+09],
#        [-1.81723912e+09],
#        [-1.89357633e+09],
#        [-1.76005239e+09],
#        [-1.65710597e+09],
#        [-1.48868122e+09],
#        [-1.60124033e+09],
#        [-1.34409443e+09]])

# %%
# 1/m * Sigma(0,m) (y_pred-y)
db = np.sum(Y_pred-Y_arr)/Y_pred.shape[1]

# %%
db
# Out:
# -4765258.803002552

# %%
W = W - (10)*dW
b = b - (10)*db

# %%
Y_pred = np.dot(W.T,X_arr)+b

# %%
second_loss = np.sum(np.square((Y_pred-Y_arr)))/(2*Y_pred.shape[1])

# %%
second_loss
# Out:
# 8.584907246720022e+27

# %%
initial_loss - second_loss
# Out:
# -8.584907246720009e+27
