# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_path = "My Uber Drives - 2016.csv.xls"

# %%
uber_data = pd.read_csv(data_path)

# %%
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
#1. What are the number of rides

# %%
uber_data.shape[0]
# Out:
# 1156

# %%
len(uber_data)
# Out:
# 1156

# %%
## Axis=0 --> Horizontal / column-wise
## Axis=1 --> Vertical / row-wise

# %%
uber_data.drop(1155,inplace=True)

# %%
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
df1 = uber_data.drop("START*",axis=1)

# %%
uber_data
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
len(uber_data)
# Out:
# 1155

# %%
unique_values = set(uber_data['START*'])
count_unique_values = {}
for unique_value in unique_values:
    count_unique_values[unique_value] = 0
for i in uber_data["START*"]:
    count_unique_values[i] += 1

# %%
for unique_value in unique_values:
    print(f"{unique_value} --> {count_unique_values[unique_value]}")
# Out:
# Long Island City --> 1
# Waverly Place --> 4
# Apex --> 17
# Burtrose --> 1
# Sugar Land --> 1
# Northwoods --> 3
# Rose Hill --> 1
# Mcvan --> 1
# Banner Elk --> 8
# Winston Salem --> 1
# Morrisville --> 85
# Central --> 8
# West Berkeley --> 5
# Townes at Everett Crossing --> 1
# Tribeca --> 1
# Islamabad --> 57
# Fayetteville Street --> 3
# Lake Wellingborough --> 1
# Kar?chi --> 27
# Washington Avenue --> 1
# Katunayaka --> 2
# San Jose --> 2
# Daytona Beach --> 1
# Eastgate --> 1
# Katy --> 1
# Downtown --> 9
# Lakeview --> 1
# South Congress --> 5
# Gulfton --> 1
# Georgian Acres --> 1
# Sharpstown --> 5
# Cory --> 1
# Jamaica --> 2
# Hell's Kitchen --> 1
# Fuquay-Varina --> 1
# Topton --> 2
# Kenner --> 11
# Gampaha --> 1
# Orlando --> 8
# Medical Centre --> 1
# Summerwinds --> 1
# NOMA --> 1
# Katunayake --> 1
# Pontchartrain Shores --> 2
# Elmhurst --> 1
# Congress Ave District --> 1
# R?walpindi --> 11
# Edgehill Farms --> 8
# West End --> 1
# Wake Co. --> 1
# ...

# %%
uber_data["START*"].value_counts()
# Out:
# START*
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: count, Length: 177, dtype: int64

# %%
type(uber_data["START*"])
# Out:
# pandas.core.series.Series

# %%
uber_start_np = uber_data["START*"].to_numpy()

# %%
uber_start_np
# Out:
# array(['Fort Pierce', 'Fort Pierce', 'Fort Pierce', ...,
#        'Unknown Location', 'Katunayake', 'Gampaha'], dtype=object)

# %%
for place in np.unique(uber_start_np):
    place_count = (uber_start_np == place).sum()
    print(f"{place} ---> {place_count}")
# Out:
# Agnew ---> 4
# Almond ---> 1
# Apex ---> 17
# Arabi ---> 1
# Arlington ---> 1
# Arlington Park at Amberly ---> 1
# Asheville ---> 2
# Austin ---> 1
# Banner Elk ---> 8
# Bellevue ---> 1
# Berkeley ---> 16
# Boone ---> 2
# Briar Meadow ---> 1
# Bryson City ---> 5
# Burtrose ---> 1
# CBD ---> 4
# Capitol One ---> 2
# Cary ---> 201
# Central ---> 8
# Chalmette ---> 1
# Chapel Hill ---> 2
# Chessington ---> 2
# College Avenue ---> 1
# Colombo ---> 8
# Columbia Heights ---> 1
# Congress Ave District ---> 1
# Connecticut Avenue ---> 1
# Convention Center District ---> 1
# Cory ---> 1
# Couples Glen ---> 2
# Covington ---> 6
# Coxville ---> 1
# Daytona Beach ---> 1
# Downtown ---> 9
# Durham ---> 37
# Eagan Park ---> 1
# Eagle Rock ---> 1
# East Austin ---> 1
# East Elmhurst ---> 2
# East Harlem ---> 1
# Eastgate ---> 1
# Edgehill Farms ---> 8
# El Cerrito ---> 1
# Elk Park ---> 1
# Elmhurst ---> 1
# Emeryville ---> 10
# Fairmont ---> 1
# Farmington Woods ---> 2
# ...

# %%
# Out:
# array([False, False, False, ..., False, False, False])
